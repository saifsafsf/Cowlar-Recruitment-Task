# %%
import pandas as pd

# %%
titanic_df = pd.read_csv('data/titanic_extended.csv')
titanic_df.head()
# Out:
#    pclass  survived                               name     sex      age  \
# 0       1         1                   Elisabeth Walton  female  29.0000
# 1       1         1                      Hudson Trevor    male   0.9167
# 2       1         0                      Helen Loraine  female   2.0000
# 3       1         0            Hudson Joshua Creighton    male  30.0000
# 4       1         0  Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin  ...       boat       body  \
# 0      0      0   24160  211.3375       B5  ...          2   survived
# 1      1      2  113781  151.5500  C22 C26  ...         11   survived
# 2      1      2  113781  151.5500  C22 C26  ...  not_found  not_found
# 3      1      2  113781  151.5500  C22 C26  ...  not_found      135.0
# 4      1      2  113781  151.5500  C22 C26  ...  not_found  not_found
#
#                          home.dest family_name    title alone  family_size  \
# ...

# %%
# Checking for any abnormal value in the column
titanic_df['sex'].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
sex_dict = {
    'female': 0,
    'male': 1
}

titanic_df['sex'].replace(sex_dict, inplace=True)

# %%
# Checking for any abnormal value in the column
titanic_df['embarked'].value_counts()
# Out:
# S    916
# C    270
# Q    123
# Name: embarked, dtype: int64

# %%
embarked_dict = {
    'S': 0,
    'C': 1,
    'Q': 2
}

titanic_df['embarked'].replace(embarked_dict, inplace=True)

# %%
# Checking for any abnormal value in the column
titanic_df['title'].value_counts()
# Out:
# Mr.              757
# Miss.            260
# Mrs.             197
# Master.           61
# Rev.               8
# Dr.                8
# Col.               4
# Mlle.              2
# Ms.                2
# Major.             2
# Capt.              1
# Sir.               1
# Dona.              1
# Jonkheer.          1
# the Countess.      1
# Don.               1
# Mme.               1
# Lady.              1
# Name: title, dtype: int64

# %%
# Abstracting the dictionary-making process
titles = titanic_df['title'].value_counts().index
title_dict = {title:index for index, title in enumerate(titles)}

titanic_df['title'].replace(title_dict, inplace=True)

# %%
# Checking for any abnormal value in the column
titanic_df['deck'].value_counts().sort_index()
# Out:
# A            22
# B            65
# C            94
# D            46
# E            41
# F            21
# G             5
# T             1
# unknown    1014
# Name: deck, dtype: int64

# %%
decks = titanic_df['deck'].value_counts().sort_index().index
deck_dict = {deck:index for index, deck in enumerate(decks)}

titanic_df['deck'].replace(deck_dict, inplace=True)

# %%
titanic_df.head()
# Out:
#    pclass  survived                               name  sex      age  sibsp  \
# 0       1         1                   Elisabeth Walton    0  29.0000      0
# 1       1         1                      Hudson Trevor    1   0.9167      1
# 2       1         0                      Helen Loraine    0   2.0000      1
# 3       1         0            Hudson Joshua Creighton    1  30.0000      1
# 4       1         0  Hudson J C (Bessie Waldo Daniels)    0  25.0000      1
#
#    parch  ticket      fare    cabin  ...       boat       body  \
# 0      0   24160  211.3375       B5  ...          2   survived
# 1      2  113781  151.5500  C22 C26  ...         11   survived
# 2      2  113781  151.5500  C22 C26  ...  not_found  not_found
# 3      2  113781  151.5500  C22 C26  ...  not_found      135.0
# 4      2  113781  151.5500  C22 C26  ...  not_found  not_found
#
#                          home.dest family_name title  alone  family_size  \
# ...

# %%
titanic_df.to_csv('data/titanic_encoded.csv', index=False)
